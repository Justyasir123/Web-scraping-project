# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("IT_job_scraping.csv")
df
# Out:
#       Unnamed: 0                                             Titles  \
# 0              0  IT Executive Jobs Opening in Gsm.pvt.ltd at As...
# 1              1  IT Manager Jobs Opening in Ideal Career Zone a...
# 2              2  Financial Analyst Jobs in Hyderabad - goldman ...
# 3              3  IT Trainer Jobs Opening in Shryze Tech at Nung...
# 4              4  IT Recruiter Jobs Opening in Uniquehire at Pan...
# ...          ...                                                ...
# 1655        1655  Python Trainer Jobs Opening in Udayan Care at ...
# 1656        1656  Site Engineer/Senior Engineer Jobs Opening in ...
# 1657        1657  Creative Content Writer Jobs Opening in UNCODE...
# 1658        1658  Junior Architect/Interior Designer Jobs Openin...
# 1659        1659  Digital Marketing Executive Jobs Opening in Ga...
#
#                                      Company      Experience  \
# 0                                Gsm.pvt.ltd         0 Years
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Titles        0
# Company       0
# Experience    0
# Salary        0
# Location      0
# dtype: int64

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Titles  \
# 0           0  IT Executive Jobs Opening in Gsm.pvt.ltd at As...
# 1           1  IT Manager Jobs Opening in Ideal Career Zone a...
# 2           2  Financial Analyst Jobs in Hyderabad - goldman ...
# 3           3  IT Trainer Jobs Opening in Shryze Tech at Nung...
# 4           4  IT Recruiter Jobs Opening in Uniquehire at Pan...
# 5           5  IT Recruiter Jobs Opening in Kanak IT Service ...
# 6           6  IT Recruiter Jobs Opening in Our Business Ladd...
# 7           7       IT Intern Jobs Opening in Pawzz at DelhiLess
# 8           8  Desktop Support Engineer Jobs in Hyderabad - F...
# 9           9  IT Assistant Jobs Opening in Kothari Internati...
#
#                              Company       Experience                  Salary  \
# 0                        Gsm.pvt.ltd          0 Years    Salary not disclosed
# 1                  Ideal Career Zone    3 to 3+ Years   15000 - 16000 Monthly
# ...

# %%
df["Titles"]=df["Titles"].str.lower().str.split("jobs").str[0]
df["Titles"]=df["Titles"].str.split("R").str[0]
df["Titles"]
# Out:
# 0                             it executive
# 1                               it manager
# 2                        financial analyst
# 3                               it trainer
# 4                             it recruiter
#                        ...
# 1655                        python trainer
# 1656         site engineer/senior engineer
# 1657               creative content writer
# 1658    junior architect/interior designer
# 1659           digital marketing executive
# Name: Titles, Length: 1660, dtype: object

# %%
df["Titles"]
# Out:
# 0                             it executive
# 1                               it manager
# 2                        financial analyst
# 3                               it trainer
# 4                             it recruiter
#                        ...
# 1655                        python trainer
# 1656         site engineer/senior engineer
# 1657               creative content writer
# 1658    junior architect/interior designer
# 1659           digital marketing executive
# Name: Titles, Length: 1660, dtype: object

# %%
df.head(10)
# Out:
#    Unnamed: 0                     Titles                            Company  \
# 0           0              it executive                         Gsm.pvt.ltd
# 1           1                it manager                   Ideal Career Zone
# 2           2         financial analyst      goldman sachs services pvt ltd
# 3           3                it trainer                         Shryze Tech
# 4           4              it recruiter                          Uniquehire
# 5           5              it recruiter                Kanak IT Service LLC
# 6           6              it recruiter                 Our Business Ladder
# 7           7                 it intern                               Pawzz
# 8           8  desktop support engineer   For a Client of Teamlease Digital
# 9           9              it assistant        Kothari International School
#
#         Experience                  Salary    Location
# 0          0 Years    Salary not disclosed       Patna
# ...

# %%
df["Experience"].unique()
# Out:
# array(['0 Years', '3 to 3+ Years', '0.6 to 3 Years', '2.5 to 3+ Years',
#        '2.5 to 3 Years', '2 to 4 Years', '0 to 3 Years', '2 to 3+ Years',
#        '4 to 10 Years', '2 to 11 Years', '1 to 3 Years', '2 to 5 Years',
#        '1 to 3+ Years', '0 to 5 Years', '0 to 0.6 Years', '2 to 3 Years',
#        '0 to 1 Years', '3+ Years', '0.6 to 3+ Years', '0.6 to 1 Years',
#        '0.6 Years', '1.5 to 3 Years', '1 to 2 Years', '0 to 2 Years',
#        '1 to 2.5 Years', '1.5 to 3+ Years', '1 Years', '0 to 3+ Years',
#        '0.6 to 2 Years', '2 Years', '1.5 Years'], dtype=object)

# %%
# Replacing specific ranges of experience with standardized values
df['Experience'] = df['Experience'].str.replace("3 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0.6 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("2.5 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("2.5 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("2 to 4 Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("2 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("4 to 10 Years", "10 Years")
df['Experience'] = df['Experience'].str.replace("2 to 11 Years", "11 Years")
df['Experience'] = df['Experience'].str.replace("1 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("2 to 5 Years", "5 Years")
df['Experience'] = df['Experience'].str.replace("1 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0 to 5 Years", "5 Years")
df['Experience'] = df['Experience'].str.replace("0 to 0.6 Years", "0.6 Years")
df['Experience'] = df['Experience'].str.replace("2 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("0 to 1 Years", "1 Years")
df['Experience'] = df['Experience'].str.replace("3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0.6 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0.6 to 1 Years", "1 Years")
df['Experience'] = df['Experience'].str.replace("0.6 Years", "1 Years")
df['Experience'] = df['Experience'].str.replace("1 to 2 Years", "2 Years")
df['Experience'] = df['Experience'].str.replace("1.5 to 3 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("0 to 2 Years", "2 Years")
df['Experience'] = df['Experience'].str.replace("1 to 2.5 Years", "3 Years")
df['Experience'] = df['Experience'].str.replace("1.5 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0 to 3+ Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("1 Years", "1 Year")
df['Experience'] = df['Experience'].str.replace("1.5 Years", "2 Years")
df['Experience'] = df['Experience'].str.replace("2 Years", "2 Years")
df['Experience'] = df['Experience'].str.replace("0.6 to 2 Years", "2 Years")
df['Experience'] = df['Experience'].str.replace("0.6 to 4 Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("1.5 to 4 Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0 to 4 Years", "4 Years")
df['Experience'] = df['Experience'].str.replace("0 Years", "Fresher")


print(df['Experience'].unique())
# Out:
# ['Fresher' '4 Years' '3 Years' '1Fresher' '11 Year' '5 Years' '1 Year'
#  '2 Years']

# %%
df.head(10)
# Out:
#    Unnamed: 0                     Titles                            Company  \
# 0           0              it executive                         Gsm.pvt.ltd
# 1           1                it manager                   Ideal Career Zone
# 2           2         financial analyst      goldman sachs services pvt ltd
# 3           3                it trainer                         Shryze Tech
# 4           4              it recruiter                          Uniquehire
# 5           5              it recruiter                Kanak IT Service LLC
# 6           6              it recruiter                 Our Business Ladder
# 7           7                 it intern                               Pawzz
# 8           8  desktop support engineer   For a Client of Teamlease Digital
# 9           9              it assistant        Kothari International School
#
#   Experience                  Salary    Location
# 0    Fresher    Salary not disclosed       Patna
# ...

# %%
blank_count1 = df['Experience'].str.match(r'^\s*$', na=False).sum()
print(blank_count1)
# Out:
# 0

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 25000 - 50000 Monthly    386
# Salary not disclosed     269
# 56000 - 76000 Monthly    242
# 55000 - 75000 Monthly    213
# 50000 - 75000 Monthly    113
#                         ...
# 16000 - 20000 Monthly      1
# 18000 - 24000 Monthly      1
# 20000 - 24000 Monthly      1
# 13000 - 17000 Monthly      1
# 20000 - 26000 Monthly      1
# Name: count, Length: 128, dtype: int64

# %%
df['Salary']=df['Salary'].replace("Salary not disclosed",np.nan)
df.head(10)
# Out:
#    Unnamed: 0                     Titles                            Company  \
# 0           0              it executive                         Gsm.pvt.ltd
# 1           1                it manager                   Ideal Career Zone
# 2           2         financial analyst      goldman sachs services pvt ltd
# 3           3                it trainer                         Shryze Tech
# 4           4              it recruiter                          Uniquehire
# 5           5              it recruiter                Kanak IT Service LLC
# 6           6              it recruiter                 Our Business Ladder
# 7           7                 it intern                               Pawzz
# 8           8  desktop support engineer   For a Client of Teamlease Digital
# 9           9              it assistant        Kothari International School
#
#   Experience                  Salary    Location
# 0    Fresher                     NaN       Patna
# ...

# %%
df['Salary'].value_counts()
# Out:
# Salary
# 25000 - 50000 Monthly     386
# 56000 - 76000 Monthly     242
# 55000 - 75000 Monthly     213
# 50000 - 75000 Monthly     113
# 45000 - 65000 Monthly      91
#                          ...
# 400000 - 800000 Yearly      1
# 16000 - 20000 Monthly       1
# 18000 - 24000 Monthly       1
# 20000 - 24000 Monthly       1
# 20000 - 26000 Monthly       1
# Name: count, Length: 127, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Titles          0
# Company         0
# Experience      0
# Salary        269
# Location        0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Titles        0
# Company       0
# Experience    0
# Salary        0
# Location      0
# dtype: int64

# %%
df["Salary"].unique()
# Out:
# array(['15000 - 16000 Monthly', '400000 - 800000 Yearly',
#        '30000 - 45000 Monthly', '10000 - 15000 Monthly',
#        '23500 - 25000 Monthly', '15000 - 20000 Monthly',
#        '13000 - 25000 Monthly', '38000 - 52000 Monthly',
#        '15000 - 25000 Monthly', '8000 - 12000 Monthly',
#        '500000 - 2000000 Yearly', '29000 - 47000 Monthly',
#        '25000 - 30000 Monthly', '2000 - 15000 Monthly',
#        '50000 - 400000 Yearly', '20000 - 40000 Monthly',
#        '28000 - 47000 Monthly', '30000 - 361000 Yearly',
#        '30000 - 40000 Monthly', '10000 - 1000000 Monthly',
#        '12000 - 15000 Monthly', '12000 - 16000 Monthly',
#        '25000 - 35000 Monthly', '20000 - 30000 Monthly',
#        '16000 - 19000 Monthly', '10000 - 22000 Monthly',
#        '80000 - 200000 Monthly', '10000 - 45000 Monthly',
#        '50000 - 80000 Monthly', '5000 - 8000 Monthly',
#        '15000 - 17000 Monthly', '20000 - 25000 Monthly',
# ...

# %%
# Split the Salary column into "Salary Min" and "Salary Max"
df["Salary"] = df['Salary'].str.split('-', expand=True)[1].str.strip()

df["Salary"]
# Out:
# 1       16000 Monthly
# 2       800000 Yearly
# 5       45000 Monthly
# 6       15000 Monthly
# 8       25000 Monthly
#             ...
# 1648    15000 Monthly
# 1652    26000 Monthly
# 1653             None
# 1654    30000 Monthly
# 1657     6000 Monthly
# Name: Salary, Length: 1391, dtype: object

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 50000 Monthly      391
# 75000 Monthly      326
# 76000 Monthly      242
# 65000 Monthly       91
# 15000 Monthly       52
# 20000 Monthly       41
# 18000 Monthly       32
# 25000 Monthly       31
# 12000 Monthly       25
# 30000 Monthly       19
# 47000 Monthly       12
# 22000 Monthly       12
# 35000 Monthly       11
# 40000 Monthly       11
# 10000 Monthly        9
# 16000 Monthly        7
# 19000 Monthly        6
# 17000 Monthly        6
# 9000 Monthly         4
# 28000 Monthly        3
# 24000 Monthly        3
# 60000 Monthly        3
# 8000 Monthly         2
# 45000 Monthly        2
# 52000 Monthly        2
# 6000 Monthly         2
# 3000000 Yearly       2
# 70000 Monthly        2
# 80000 Monthly        2
# 100000 Monthly       2
# 200000 Yearly        2
# 14000 Monthly        1
# 5000 Monthly         1
# 250000 Monthly       1
# 7500 Monthly         1
# 43000 Monthly        1
# 600000 Yearly        1
# 29000 Monthly        1
# 23000 Monthly        1
# ...

# %%
df["Salary"]=df["Salary"].str.replace("2000000 Yearly",str(2000000/12))
df["Salary"]=df["Salary"].str.replace("800000 Yearly",str(800000/12))
df["Salary"]=df["Salary"].str.replace("400000 Yearly",str(400000/12))
df["Salary"]=df["Salary"].str.replace("361000 Yearly",str(361000/12))
df["Salary"]=df["Salary"].str.replace("200000 Yearly",str(200000/12))

df["Salary"].unique()
# Out:
# array(['16000 Monthly', '66666.66666666667', '45000 Monthly',
#        '15000 Monthly', '25000 Monthly', '20000 Monthly', '52000 Monthly',
#        '12000 Monthly', '166666.66666666666', '47000 Monthly',
#        '30000 Monthly', '33333.333333333336', '40000 Monthly',
#        '30083.333333333332', '1000000 Monthly', '35000 Monthly',
#        '19000 Monthly', '22000 Monthly', '200000 Monthly',
#        '80000 Monthly', '8000 Monthly', '17000 Monthly', '18000 Monthly',
#        '24000 Monthly', '60000 Monthly', '16666.666666666668',
#        '10000 Monthly', '50000 Monthly', '9000 Monthly', '28000 Monthly',
#        '37500 Monthly', None, '870000 Yearly', '70000 Monthly',
#        '3000000 Yearly', '76000 Monthly', '75000 Monthly',
#        '74000 Monthly', '240000 Yearly', '58333 Monthly',
#        '125000 Monthly', '14000 Monthly', '22500 Monthly',
#        '65000 Monthly', '29000 Monthly', '600000 Yearly', '6000 Monthly',
# ...

# %%
df["Salary"].value_counts()
# Out:
# Salary
# 50000 Monthly         391
# 75000 Monthly         326
# 76000 Monthly         242
# 65000 Monthly          91
# 15000 Monthly          52
# 20000 Monthly          41
# 18000 Monthly          32
# 25000 Monthly          31
# 12000 Monthly          25
# 30000 Monthly          19
# 47000 Monthly          12
# 22000 Monthly          12
# 35000 Monthly          11
# 40000 Monthly          11
# 10000 Monthly           9
# 16000 Monthly           7
# 19000 Monthly           6
# 17000 Monthly           6
# 9000 Monthly            4
# 28000 Monthly           3
# 24000 Monthly           3
# 60000 Monthly           3
# 8000 Monthly            2
# 45000 Monthly           2
# 52000 Monthly           2
# 6000 Monthly            2
# 3000000 Yearly          2
# 70000 Monthly           2
# 80000 Monthly           2
# 100000 Monthly          2
# 16666.666666666668      2
# 14000 Monthly           1
# 5000 Monthly            1
# 250000 Monthly          1
# 7500 Monthly            1
# ...

# %%
df["Salary"]=df["Salary"].str.split(" ").str[0]

# %%
df["Salary"].unique()
# Out:
# array(['16000', '66666.66666666667', '45000', '15000', '25000', '20000',
#        '52000', '12000', '166666.66666666666', '47000', '30000',
#        '33333.333333333336', '40000', '30083.333333333332', '1000000',
#        '35000', '19000', '22000', '200000', '80000', '8000', '17000',
#        '18000', '24000', '60000', '16666.666666666668', '10000', '50000',
#        '9000', '28000', '37500', None, '870000', '70000', '3000000',
#        '76000', '75000', '74000', '240000', '58333', '125000', '14000',
#        '22500', '65000', '29000', '600000', '6000', '250000', '5000',
#        '100000', '7500', '43000', '23000', '26000'], dtype=object)

# %%
df["Salary"]=df["Salary"].str.split(".").str[0]

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce').astype('Int64')

# %%
df["Salary"].unique()
# Out:
# <IntegerArray>
# [  16000,   66666,   45000,   15000,   25000,   20000,   52000,   12000,
#   166666,   47000,   30000,   33333,   40000,   30083, 1000000,   35000,
#    19000,   22000,  200000,   80000,    8000,   17000,   18000,   24000,
#    60000,   16666,   10000,   50000,    9000,   28000,   37500,    <NA>,
#   870000,   70000, 3000000,   76000,   75000,   74000,  240000,   58333,
#   125000,   14000,   22500,   65000,   29000,  600000,    6000,  250000,
#     5000,  100000,    7500,   43000,   23000,   26000]
# Length: 54, dtype: Int64

# %%
df["Salary"].isnull().sum()
# Out:
# 14

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Titles        0
# Company       0
# Experience    0
# Salary        0
# Location      0
# dtype: int64

# %%
df=df.drop("Unnamed: 0",axis=1)
df
# Out:
#                              Titles                                 Company  \
# 1                       it manager                        Ideal Career Zone
# 2                financial analyst           goldman sachs services pvt ltd
# 5                     it recruiter                     Kanak IT Service LLC
# 6                     it recruiter                      Our Business Ladder
# 8         desktop support engineer        For a Client of Teamlease Digital
# ...                             ...                                     ...
# 1647  business development manager       Point Perfect Technology Solutions
# 1648                    telecaller                 JOB PROVIDER CONSULTANCY
# 1652          operations executive                    Medyseva Technologies
# 1654     technical sales executive               ByteReboot Private Limited
# 1657       creative content writer   UNCODE Inc- AJR Info Systems Pvt. Ltd.
#
#      Experience  Salary     Location
# ...

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#                                                  Titles  \
# 1                                           it manager
# 2                                    financial analyst
# 5                                         it recruiter
# 6                                         it recruiter
# 8                             desktop support engineer
# 10                                          it trainer
# 13                        hr recruiter - it and non it
# 15                                it software engineer
# 16                                     us it recruiter
# 17                                     hr it recruiter
# 19                                it software engineer
# 20                                it software engineer
# 21                                it software engineer
# 22                                 it network engineer
# 23                                it software engineer
# 24                                  it sales executive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1377 entries, 1 to 1657
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Titles      1377 non-null   object
#  1   Company     1377 non-null   object
#  2   Experience  1377 non-null   object
#  3   Salary      1377 non-null   Int64
#  4   Location    1377 non-null   object
# dtypes: Int64(1), object(4)
# memory usage: 65.9+ KB

# %%
df.to_csv("IT_job_scraping_cleaned.csv",index=False)
